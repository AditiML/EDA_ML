# %% [markdown]
# ### Load all packages in Python

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import functools

# %%
#Load all Data from CSV

# %%
df = pd.read_csv('consolidated_coin_data.csv')
df.Date=pd.to_datetime(df.Date)
df = df[::-1]
df.head()
# Out:
#       Currency       Date   Open   High   Low  Close     Volume Market Cap
# 97255  zencash 2017-06-01  10.75  21.80  9.67  11.33      3,196          -
# 97254  zencash 2017-06-02  11.34  14.48  6.86   9.09     23,401          -
# 97253  zencash 2017-06-03   9.08  17.69  5.50   9.16     23,728          -
# 97252  zencash 2017-06-04   9.13  13.86  5.16  10.32     26,662          -
# 97251  zencash 2017-06-05  10.57  19.06  8.11  19.06  3,495,730          -

# %%
crypto_coin = []
crypto_list = []
for i in df.Currency.unique():
    # we only take crypto coin that got more than 200 rows
    if df[df.Currency==i][['Date','Close']].shape[0] > 200:
        crypto_coin.append(df[df.Currency==i][['Date','Close']])
        crypto_list.append(i)

# %%
crypto_list
# Out:
# ['zencash',
#  'zcoin',
#  'zclassic',
#  'zcash',
#  'xtrabytes',
#  'xp',
#  'wings',
#  'whitecoin',
#  'waves',
#  'voxels',
#  'viacoin',
#  'vertcoin',
#  'veritaseum',
#  'verge',
#  'ubiq',
#  'triggers',
#  'tether',
#  'syscoin',
#  'supernet-unity',
#  'stratis',
#  'stellar',
#  'steem',
#  'skycoin',
#  'singulardtv',
#  'sibcoin',
#  'siacoin',
#  'shift',
#  'salus',
#  'rlc',
#  'rise',
#  'ripple',
#  'reddcoin',
#  'raiblocks',
#  'quantum-resistant-ledger',
#  'qtum',
#  'pura',
#  'potcoin',
#  'pivx',
#  'pepe-cash',
#  'peercoin',
#  'paccoin',
#  'nxt',
#  'nexus',
#  'neo',
#  'nem',
#  'nav-coin',
#  'namecoin',
#  'monero',
#  'monacoin',
#  'metaverse',
#  'mercury',
#  'melon',
#  'maidsafecoin',
#  'lykke',
#  'litecoin',
#  'lisk',
#  'library-credit',
#  'komodo',
#  'ion',
#  'iconomi',
#  'humaniq',
#  'hempcoin',
#  'guppy',
#  'gulden',
#  'groestlcoin',
#  'golem-network-tokens',
#  'gnosis-gno',
#  'gamecredits',
#  'firstblood',
#  'feathercoin',
#  'faircoin',
#  'factom',
#  'ethereum',
#  'ethereum-classic',
#  'emercoin',
#  'einsteinium',
#  'edgeless',
#  'dogecoin',
#  'digixdao',
#  'digitalnote',
#  'digibyte',
#  'decred',
#  'decent',
#  'dash',
#  'counterparty',
#  'cloakcoin',
#  'bytecoin-bcn',
#  'byteball',
#  'burst',
#  'blocknet',
#  'blackcoin',
#  'bitshares',
#  'bitconnect',
#  'bitcoindark',
#  'bitcoin',
#  'bitbay',
#  'basic-attention-token',
#  'augur',
#  'asch',
#  'ark',
#  'ardor',
#  'aragon',
#  'agoras-tokens',
#  'aeternity',
#  'aeon']

# %%
concatenated=functools.reduce(lambda left,right: pd.merge(left,right,on='Date',how='left' if left.shape[0] > right.shape[0] else 'right'), crypto_coin)
# Out:
# <ipython-input-7-30623e8d1302>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Close_x'} in the result is deprecated and will raise a MergeError in a future version.
#   concatenated=functools.reduce(lambda left,right: pd.merge(left,right,on='Date',how='left' if left.shape[0] > right.shape[0] else 'right'), crypto_coin)

# %%
print(concatenated.shape)
concatenated.head(200)
# Out:
# (1705, 106)
#           Date  Close_x  Close_y  Close_x  Close_y  Close_x  Close_y  Close_x  \
# 0   2013-04-28      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1   2013-04-29      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2   2013-04-30      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3   2013-05-01      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4   2013-05-02      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ..         ...      ...      ...      ...      ...      ...      ...      ...
# 195 2013-11-09      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 196 2013-11-10      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 197 2013-11-11      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 198 2013-11-12      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 199 2013-11-13      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#      Close_y  Close_x  Close_y  Close_x  Close_y  Close_x  Close_y  Close_x  \
# 0        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 195      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 196      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 197      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 199      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#      Close_y  Close_x  Close_y  Close_x  Close_y  Close_x  Close_y  Close_x  \
# 0        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 195      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 196      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 197      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 199      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#      Close_y  Close_x  Close_y  Close_x  Close_y  Close_x  Close_y   Close_x  \
# 0        NaN      NaN      NaN      NaN      NaN      NaN      NaN       NaN
# 1        NaN      NaN      NaN      NaN      NaN      NaN      NaN       NaN
# 2        NaN      NaN      NaN      NaN      NaN      NaN      NaN       NaN
# 3        NaN      NaN      NaN      NaN      NaN      NaN      NaN       NaN
# 4        NaN      NaN      NaN      NaN      NaN      NaN      NaN       NaN
# ..       ...      ...      ...      ...      ...      ...      ...       ...
# 195      NaN      NaN      NaN      NaN      NaN      NaN      NaN  0.008653
# 196      NaN      NaN      NaN      NaN      NaN      NaN      NaN  0.008609
# 197      NaN      NaN      NaN      NaN      NaN      NaN      NaN  0.008681
# 198      NaN      NaN      NaN      NaN      NaN      NaN      NaN  0.009557
# 199      NaN      NaN      NaN      NaN      NaN      NaN      NaN  0.010846
#
#      Close_y  Close_x  Close_y  Close_x  Close_y  Close_x  Close_y  Close_x  \
# 0        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 195      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 196      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 197      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 199      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#       Close_y  Close_x  Close_y  Close_x  Close_y  Close_x  Close_y   Close_x  \
# 0    0.386525      NaN      NaN      NaN      NaN      NaN      NaN  1.110000
# 1    0.408861      NaN      NaN      NaN      NaN      NaN      NaN  1.330000
# 2    0.375300      NaN      NaN      NaN      NaN      NaN      NaN  1.500000
# 3    0.322892      NaN      NaN      NaN      NaN      NaN      NaN  1.210000
# 4    0.278807      NaN      NaN      NaN      NaN      NaN      NaN  1.070000
# ..        ...      ...      ...      ...      ...      ...      ...       ...
# 195  0.576487      NaN      NaN      NaN      NaN      NaN      NaN  0.668047
# 196  0.614046      NaN      NaN      NaN      NaN      NaN      NaN  0.636909
# 197  0.630090      NaN      NaN      NaN      NaN      NaN      NaN  0.623241
# 198  0.644991      NaN      NaN      NaN      NaN      NaN      NaN  0.576528
# 199  0.664013      NaN      NaN      NaN      NaN      NaN      NaN  0.615129
#
#      Close_y  Close_x  Close_y  Close_x  Close_y  Close_x  Close_y  Close_x  \
# 0        NaN      NaN      NaN      NaN      NaN      NaN      NaN     4.35
# 1        NaN      NaN      NaN      NaN      NaN      NaN      NaN     4.38
# 2        NaN      NaN      NaN      NaN      NaN      NaN      NaN     4.30
# 3        NaN      NaN      NaN      NaN      NaN      NaN      NaN     3.80
# 4        NaN      NaN      NaN      NaN      NaN      NaN      NaN     3.37
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 195      NaN      NaN      NaN      NaN      NaN      NaN      NaN     4.22
# 196      NaN      NaN      NaN      NaN      NaN      NaN      NaN     3.93
# 197      NaN      NaN      NaN      NaN      NaN      NaN      NaN     4.00
# 198      NaN      NaN      NaN      NaN      NaN      NaN      NaN     3.98
# 199      NaN      NaN      NaN      NaN      NaN      NaN      NaN     4.11
#
#      Close_y  Close_x  Close_y  Close_x  Close_y  Close_x  Close_y  Close_x  \
# 0        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 195      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 196      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 197      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 199      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#      Close_y  Close_x  Close_y  Close_x  Close_y  Close_x   Close_y  Close_x  \
# 0        NaN      NaN      NaN      NaN      NaN      NaN       NaN      NaN
# 1        NaN      NaN      NaN      NaN      NaN      NaN       NaN      NaN
# 2        NaN      NaN      NaN      NaN      NaN      NaN       NaN      NaN
# 3        NaN      NaN      NaN      NaN      NaN      NaN       NaN      NaN
# 4        NaN      NaN      NaN      NaN      NaN      NaN       NaN      NaN
# ..       ...      ...      ...      ...      ...      ...       ...      ...
# 195      NaN      NaN      NaN      NaN      NaN      NaN  0.111906      NaN
# 196      NaN      NaN      NaN      NaN      NaN      NaN  0.107785      NaN
# 197      NaN      NaN      NaN      NaN      NaN      NaN  0.102732      NaN
# 198      NaN      NaN      NaN      NaN      NaN      NaN  0.104496      NaN
# 199      NaN      NaN      NaN      NaN      NaN      NaN  0.073327      NaN
#
#      Close_y  Close_x  Close_y  Close_x  Close_y  Close_x  Close_y  Close_x  \
# 0        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 195      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 196      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 197      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 199      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#      Close_y  Close_x  Close_y  Close_x  Close_y  Close_x  Close_y  Close_x  \
# 0        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 195      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 196      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 197      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 199      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#      Close_y  Close_x  Close_y  Close_x  Close_y  Close_x  Close_y  Close_x  \
# 0        NaN      NaN      NaN      NaN      NaN      NaN      NaN   134.21
# 1        NaN      NaN      NaN      NaN      NaN      NaN      NaN   144.54
# 2        NaN      NaN      NaN      NaN      NaN      NaN      NaN   139.00
# 3        NaN      NaN      NaN      NaN      NaN      NaN      NaN   116.99
# 4        NaN      NaN      NaN      NaN      NaN      NaN      NaN   105.21
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 195      NaN      NaN      NaN      NaN      NaN      NaN      NaN   339.11
# 196      NaN      NaN      NaN      NaN      NaN      NaN      NaN   326.62
# 197      NaN      NaN      NaN      NaN      NaN      NaN      NaN   342.44
# 198      NaN      NaN      NaN      NaN      NaN      NaN      NaN   360.33
# 199      NaN      NaN      NaN      NaN      NaN      NaN      NaN   407.37
#
#      Close_y  Close_x  Close_y  Close_x  Close_y  Close_x  Close_y  Close_x  \
# 0        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 195      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 196      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 197      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 199      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#      Close_y  Close
# 0        NaN    NaN
# 1        NaN    NaN
# 2        NaN    NaN
# 3        NaN    NaN
# 4        NaN    NaN
# ..       ...    ...
# 195      NaN    NaN
# 196      NaN    NaN
# 197      NaN    NaN
# 198      NaN    NaN
# 199      NaN    NaN
#
# [200 rows x 106 columns]

# %%
pd.options.display.max_columns = None

# %%
correlation_set=pd.DataFrame(MinMaxScaler().fit_transform(concatenated.iloc[:,1:].dropna()), columns = crypto_list)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(20,20))
sns.heatmap(correlation_set.corr())
plt.show()

# %% [markdown]
# #### We are checking Top 20 coins those are correlated with BitCoin

# %%
bitcoin_correlation = correlation_set.corr().iloc[:,crypto_list.index('bitcoin')].values
ind = (-bitcoin_correlation).argsort()[:20]
for i in ind:
    print(crypto_list[i],bitcoin_correlation[i])
# Out:
# bitcoin 1.0
# monacoin 0.9633967191102134
# vertcoin 0.9474393512093512
# monero 0.9413217897570323
# bitconnect 0.9322278625552576
# feathercoin 0.9308061306753569
# mercury 0.9303179533355281
# whitecoin 0.9293002446773441
# pepe-cash 0.9280720809180322
# aeon 0.9213389913652484
# dash 0.918661582094414
# einsteinium 0.9081464224774877
# zencash 0.8993593774251759
# stellar 0.8957724196682152
# groestlcoin 0.8852062534244874
# litecoin 0.8815375185459681
# ethereum 0.8786689996922888
# waves 0.8555513563889096
# viacoin 0.8543533291991807
# potcoin 0.8540520171568806

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(20,20))
ind = (-bitcoin_correlation).argsort()[:6]
for i in ind:
    plt.plot(correlation_set.iloc[:, i])
plt.legend()
x_range_date = np.arange(correlation_set.shape[0])
plt.xticks(x_range_date[::60], concatenated.Date.iloc[::60])
plt.title('top 5 most trending with bitcoin')
plt.show()
# Out:
# No handles with labels found to put in legend.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-03db2ab437aa> in <module>
#       6 plt.legend()
#       7 x_range_date = np.arange(correlation_set.shape[0])
# ----> 8 plt.xticks(x_range_date[::60], concatenated.Date.iloc[::60])
#       9 plt.title('top 5 most trending with bitcoin')
#      10 plt.show()
#
# c:\users\admanna\miniconda3\envs\jlp\lib\site-packages\matplotlib\pyplot.py in xticks(ticks, labels, **kwargs)
#    1812         labels = ax.get_xticklabels()
#    1813     else:
# -> 1814         labels = ax.set_xticklabels(labels, **kwargs)
#    1815     for l in labels:
#    1816         l.update(kwargs)
#
# c:\users\admanna\miniconda3\envs\jlp\lib\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      71
#      72         def wrapper(self, *args, **kwargs):
# ---> 73             return get_method(self)(*args, **kwargs)
#      74
#      75         wrapper.__module__ = owner.__module__
#
# c:\users\admanna\miniconda3\envs\jlp\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# c:\users\admanna\miniconda3\envs\jlp\lib\site-packages\matplotlib\axis.py in _set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1788         if fontdict is not None:
#    1789             kwargs.update(fontdict)
# -> 1790         return self.set_ticklabels(labels, minor=minor, **kwargs)
#    1791
#    1792     def set_ticks(self, ticks, *, minor=False):
#
# c:\users\admanna\miniconda3\envs\jlp\lib\site-packages\matplotlib\axis.py in set_ticklabels(self, ticklabels, minor, **kwargs)
#    1709             # remove all tick labels, so only error for > 0 ticklabels
#    1710             if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
# -> 1711                 raise ValueError(
#    1712                     "The number of FixedLocator locations"
#    1713                     f" ({len(locator.locs)}), usually from a call to"
#
# ValueError: The number of FixedLocator locations (4), usually from a call to set_ticks, does not match the number of ticklabels (29).

# %% [markdown]
# ### Top 20 least correlated with bitcoin

# %%
ind = (bitcoin_correlation).argsort()[:20]
for i in ind:
    print(crypto_list[i],bitcoin_correlation[i])
# Out:
# iconomi -0.3678370746272109
# lykke -0.3405434470636257
# firstblood -0.2764670657377715
# gnosis-gno -0.26397010074550575
# decent -0.2627419594759297
# byteball -0.1497786611444359
# library-credit -0.012438111097779278
# aeternity 0.012846957769092655
# singulardtv 0.0323602808370106
# gamecredits 0.06880385191123409
# metaverse 0.0840019830795055
# aragon 0.17879141149135933
# golem-network-tokens 0.219813099390874
# emercoin 0.2778635678847037
# siacoin 0.2806459454418357
# gulden 0.3478051958962515
# digibyte 0.36640215839744045
# zclassic 0.37878265158892355
# blackcoin 0.3931884831815012
# tether 0.4036272732923581

# %%
plt.figure(figsize=(20,20))
ind = (bitcoin_correlation).argsort()[:6]
for i in ind:
    plt.plot(correlation_set.iloc[:, i])
plt.legend()
x_range_date = np.arange(correlation_set.shape[0])
plt.xticks(x_range_date[::60], concatenated.Date.iloc[::60])
plt.title('top 6 least trending with bitcoin')
plt.show()
# Out:
# No handles with labels found to put in legend.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-1fc49b5899ca> in <module>
#       5 plt.legend()
#       6 x_range_date = np.arange(correlation_set.shape[0])
# ----> 7 plt.xticks(x_range_date[::60], concatenated.Date.iloc[::60])
#       8 plt.title('top 6 least trending with bitcoin')
#       9 plt.show()
#
# c:\users\admanna\miniconda3\envs\jlp\lib\site-packages\matplotlib\pyplot.py in xticks(ticks, labels, **kwargs)
#    1812         labels = ax.get_xticklabels()
#    1813     else:
# -> 1814         labels = ax.set_xticklabels(labels, **kwargs)
#    1815     for l in labels:
#    1816         l.update(kwargs)
#
# c:\users\admanna\miniconda3\envs\jlp\lib\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      71
#      72         def wrapper(self, *args, **kwargs):
# ---> 73             return get_method(self)(*args, **kwargs)
#      74
#      75         wrapper.__module__ = owner.__module__
#
# c:\users\admanna\miniconda3\envs\jlp\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# c:\users\admanna\miniconda3\envs\jlp\lib\site-packages\matplotlib\axis.py in _set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1788         if fontdict is not None:
#    1789             kwargs.update(fontdict)
# -> 1790         return self.set_ticklabels(labels, minor=minor, **kwargs)
#    1791
#    1792     def set_ticks(self, ticks, *, minor=False):
#
# c:\users\admanna\miniconda3\envs\jlp\lib\site-packages\matplotlib\axis.py in set_ticklabels(self, ticklabels, minor, **kwargs)
#    1709             # remove all tick labels, so only error for > 0 ticklabels
#    1710             if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
# -> 1711                 raise ValueError(
#    1712                     "The number of FixedLocator locations"
#    1713                     f" ({len(locator.locs)}), usually from a call to"
#
# ValueError: The number of FixedLocator locations (4), usually from a call to set_ticks, does not match the number of ticklabels (29).

# %% [markdown]
# ### we check Ethereum, top 20 most and least

# %%
e_correlation = correlation_set.corr().iloc[:,crypto_list.index('ethereum')].values
ind = (-e_correlation).argsort()[:20]
for i in ind:
    print(crypto_list[i],e_correlation[i])
# Out:
# ethereum 1.0
# decred 0.9564361556310613
# waves 0.9549242013350402
# digixdao 0.938807816482058
# dash 0.9360282042023732
# stellar 0.9357259549501971
# monero 0.9321768016411426
# litecoin 0.9306036397722518
# whitecoin 0.9258902317660859
# zcash 0.9158117964696001
# ardor 0.9145225592824098
# syscoin 0.9139179335574771
# counterparty 0.9120910813371478
# zcoin 0.9109307542856803
# mercury 0.9080165393813344
# feathercoin 0.9021903087490352
# bitbay 0.8984051145243782
# viacoin 0.8982279972052833
# nem 0.8950842077420491
# bitcoin 0.8786689996922888

# %%
plt.figure(figsize=(20,20))
ind = (-e_correlation).argsort()[:6]
for i in ind:
    plt.plot(correlation_set.iloc[:, i])
plt.legend()
x_range_date = np.arange(correlation_set.shape[0])
plt.xticks(x_range_date[::60], concatenated.Date.iloc[::60])
plt.title('top 6 most trending with Ethereum')
plt.show()
# Out:
# No handles with labels found to put in legend.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-72799ec8f36f> in <module>
#       5 plt.legend()
#       6 x_range_date = np.arange(correlation_set.shape[0])
# ----> 7 plt.xticks(x_range_date[::60], concatenated.Date.iloc[::60])
#       8 plt.title('top 6 most trending with Ethereum')
#       9 plt.show()
#
# c:\users\admanna\miniconda3\envs\jlp\lib\site-packages\matplotlib\pyplot.py in xticks(ticks, labels, **kwargs)
#    1812         labels = ax.get_xticklabels()
#    1813     else:
# -> 1814         labels = ax.set_xticklabels(labels, **kwargs)
#    1815     for l in labels:
#    1816         l.update(kwargs)
#
# c:\users\admanna\miniconda3\envs\jlp\lib\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      71
#      72         def wrapper(self, *args, **kwargs):
# ---> 73             return get_method(self)(*args, **kwargs)
#      74
#      75         wrapper.__module__ = owner.__module__
#
# c:\users\admanna\miniconda3\envs\jlp\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# c:\users\admanna\miniconda3\envs\jlp\lib\site-packages\matplotlib\axis.py in _set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1788         if fontdict is not None:
#    1789             kwargs.update(fontdict)
# -> 1790         return self.set_ticklabels(labels, minor=minor, **kwargs)
#    1791
#    1792     def set_ticks(self, ticks, *, minor=False):
#
# c:\users\admanna\miniconda3\envs\jlp\lib\site-packages\matplotlib\axis.py in set_ticklabels(self, ticklabels, minor, **kwargs)
#    1709             # remove all tick labels, so only error for > 0 ticklabels
#    1710             if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
# -> 1711                 raise ValueError(
#    1712                     "The number of FixedLocator locations"
#    1713                     f" ({len(locator.locs)}), usually from a call to"
#
# ValueError: The number of FixedLocator locations (4), usually from a call to set_ticks, does not match the number of ticklabels (29).

# %%
ind = (e_correlation).argsort()[:20]
for i in ind:
    print(crypto_list[i],e_correlation[i])
# Out:
# lykke -0.24849904611236265
# iconomi -0.13253620335757055
# decent -0.013205093026416318
# firstblood -0.010694476658377026
# gnosis-gno 0.015708429046852386
# byteball 0.13621831212570798
# metaverse 0.22428630598026433
# singulardtv 0.3160598235161496
# library-credit 0.31778395394536524
# aeternity 0.33323312753568196
# tether 0.391558312203324
# gamecredits 0.4118699683508911
# zclassic 0.5282677494043
# pura 0.5368081751439734
# aragon 0.5427378402771099
# golem-network-tokens 0.5554860082024186
# emercoin 0.5630138194723401
# siacoin 0.5845303668924772
# veritaseum 0.598547434122964
# gulden 0.6033069159486489

# %%
plt.figure(figsize=(20,10))
ripple=df[df.Currency=='ripple'][['Date','Close']]
ripple_shifted = ripple - ripple.shift(31)
mean_month=pd.rolling_mean(ripple.Close, window=31).values
regr.fit(np.arange(mean_month[31:].shape[0]).reshape((-1,1)), mean_month[31:].reshape((-1,1)))
future_linear=regr.predict(np.arange(mean_month.shape[0]+1000).reshape((-1,1)))[:,0]
plt.plot(ripple.Close.values, label = 'normal close')
plt.plot(ripple_shifted.Close.values, label = 'minus month shifted')
plt.plot(ripple.shift(31).Close.values, label = 'month shifted')
plt.plot(mean_month, label = 'mean every month')
plt.plot(future_linear, label='linear future moving mean')
plt.xticks(np.arange(ripple.shape[0])[::380], ripple.Date.iloc[::380])
plt.legend()
plt.title('ripple analysis')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-fd78496b3d24> in <module>
#       2 ripple=df[df.Currency=='ripple'][['Date','Close']]
#       3 ripple_shifted = ripple - ripple.shift(31)
# ----> 4 mean_month=pd.rolling_mean(ripple.Close, window=31).values
#       5 regr.fit(np.arange(mean_month[31:].shape[0]).reshape((-1,1)), mean_month[31:].reshape((-1,1)))
#       6 future_linear=regr.predict(np.arange(mean_month.shape[0]+1000).reshape((-1,1)))[:,0]
#
# c:\users\admanna\miniconda3\envs\jlp\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'rolling_mean'
